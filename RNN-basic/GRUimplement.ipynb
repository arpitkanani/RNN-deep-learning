# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense,GRU,Input
from keras.datasets import imdb

# %%
(X_train,y_train),(X_test,y_test)=imdb.load_data(num_words=10000)

# %%
max_len=500
X_train=pad_sequences(X_train,padding='post',maxlen=100)
X_test=pad_sequences(X_test,padding='post',maxlen=100)

# %%
X_train[0].shape,y_train[0]
# Out:
# ((100,), np.int64(1))

# %%
X_train.shape,y_test.shape
# Out:
# ((25000, 2494), (25000,))

# %%
model=Sequential()
#model.add(Input(shape=(500,)))
model.add(Embedding(2494,100,input_length=2494))
model.add(GRU(32,return_sequences=False))
model.add(Dense(1,activation='sigmoid'))
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
model.build(input_shape=(None, 2494))
model.summary()
# Out:
# e:\Deep Learning\venv\lib\site-packages\keras\src\layers\core\embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential_16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_14 (Embedding)        │ (None, 2494, 100)      │       249,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_13 (GRU)                    │ (None, 32)             │        12,864 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 262,297 (1.00 MB)
#  Trainable params: 262,297 (1.00 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.fit(X_train,y_train,epochs=10,steps_per_epoch=15,validation_steps=15,batch_size=64,validation_data=(X_test,y_test))
# Out:
# Epoch 1/10
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.4885 - loss: 0.6949 - val_accuracy: 0.4760 - val_loss: 0.6941
# Epoch 2/10
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.5271 - loss: 0.6918 - val_accuracy: 0.4760 - val_loss: 0.6992
# Epoch 3/10
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.4802 - loss: 0.6963 - val_accuracy: 0.5240 - val_loss: 0.6927
# Epoch 4/10
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.4938 - loss: 0.6937 - val_accuracy: 0.4760 - val_loss: 0.6933
# Epoch 5/10
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.4979 - loss: 0.6936 - val_accuracy: 0.5240 - val_loss: 0.6924
# Epoch 6/10
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.5031 - loss: 0.6953 - val_accuracy: 0.5240 - val_loss: 0.6920
# Epoch 7/10
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.4854 - loss: 0.6937 - val_accuracy: 0.4760 - val_loss: 0.6935
# Epoch 8/10
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.5042 - loss: 0.6936 - val_accuracy: 0.4760 - val_loss: 0.6948
# Epoch 9/10
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.4802 - loss: 0.6940 - val_accuracy: 0.5240 - val_loss: 0.6925
# Epoch 10/10
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.4833 - loss: 0.6937 - val_accuracy: 0.4760 - val_loss: 0.6936
