# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense,GRU,Input,SimpleRNN, Bidirectional

from keras.datasets import imdb

# %%
(X_train,y_train),(X_test,y_test)=imdb.load_data(num_words=10000)
max_len=500
X_train = pad_sequences(X_train, padding='post')
X_test  = pad_sequences(X_test,  padding='post')

model = Sequential()
model.add(Embedding(10000, 100, input_length=2494))
model.add(Bidirectional(GRU(32)))
model.add(Dense(1, activation='sigmoid'))

model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

model.build(input_shape=(None, 500))
model.summary()

model.fit(
    X_train, y_train,
    epochs=10,
    batch_size=64,
    validation_data=(X_test, y_test)
)
# Out:
# Model: "sequential_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_8 (Embedding)         │ (None, 500, 100)       │     1,000,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_3 (Bidirectional) │ (None, 64)             │        25,728 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,025,793 (3.91 MB)
#  Trainable params: 1,025,793 (3.91 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 129s 323ms/step - accuracy: 0.7200 - loss: 0.5338 - val_accuracy: 0.8116 - val_loss: 0.4323
# Epoch 2/10
# ...

# %%
model=Sequential()
#model.add(Input(shape=(500,)))
model.add(Embedding(10000,100,input_length=2494))
model.add( Bidirectional(LSTM(32,return_sequences=False)))
model.add(Dense(1,activation='sigmoid'))


model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])


model.build(input_shape=(None, 2494))
model.summary()


model.fit(X_train,y_train,epochs=10,steps_per_epoch=15,validation_steps=15,batch_size=64,validation_data=(X_test,y_test))

# %%
model=Sequential()
#model.add(Input(shape=(500,)))
model.add(Embedding(10000,100,input_length=2494))
model.add(Bidirectional(SimpleRNN(32,return_sequences=False)))
model.add(Dense(1,activation='sigmoid'))


model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])


model.build(input_shape=(None, 2494))
model.summary()


model.fit(X_train,y_train,epochs=10,steps_per_epoch=15,validation_steps=15,batch_size=64,validation_data=(X_test,y_test))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 4
#       2 #model.add(Input(shape=(500,)))
#       3 model.add(Embedding(2494,100,input_length=2494))
# ----> 4 model.add(Bidirectoinal(SimpleRNN(32,return_sequences=False)))
#       5 model.add(Dense(1,activation='sigmoid'))
#       6 model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
#
# NameError: name 'Bidirectoinal' is not defined
